# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('ksprojects.csv')
df
# Out:
#                id                                               name  \
# 0      1147015301  "All We Had" Gets Into Cannes -- $10 or More G...
# 1      1100844465                                       daily digest
# 2      1316334968                             Drive A Faster Car 2.0
# 3      1304906577         Accidental to Edinburgh - PHASE 1: AIRFARE
# 4      1099226462          Logical Guess Pictures' 2nd Horror Movie!
# 5      1301564845  Anatomy of a Credibility Meltdown — a book abo...
# 6      1081313636  No-bit: An artist book of analog drawings insp...
# 7       112916020          UNINSURED LA™: Support Health Care Reform
# 8      1130941392                             Hand made guitar picks
# 9      1125367305            Meeting Andrei Tarkovsky - Film Website
# 10     1143904247                            It Might Become a Movie
# 11     1163942232             Obscurae: a photo show for Braddock PA
# 12     1167151653                        Smogr Alert Field Recording
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65418 entries, 0 to 65417
# Data columns (total 13 columns):
# id               65418 non-null int64
# name             65418 non-null object
# category         65418 non-null object
# main_category    65418 non-null object
# deadline         65418 non-null object
# goal             65418 non-null float64
# launched         65418 non-null object
# state            65418 non-null object
# backers          65418 non-null int64
# country          65418 non-null object
# usd_pledged      64673 non-null float64
# currency         65418 non-null object
# pledged          65418 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 6.5+ MB

# %%
# question 1 - number of rows:
df.shape[0]
# Out:
# 65418

# %%
#q-2 What are the names and data types of the columns? data types of all:
df.dtypes
# Out:
# id                 int64
# name              object
# category          object
# main_category     object
# deadline          object
# goal             float64
# launched          object
# state             object
# backers            int64
# country           object
# usd_pledged      float64
# currency          object
# pledged          float64
# dtype: object

# %%
#q-2 column names and data type.
df.columns
# Out:
# Index(['id', 'name', 'category', 'main_category', 'deadline', 'goal',
#        'launched', 'state', 'backers', 'country', 'usd_pledged', 'currency',
#        'pledged', 'average_per_backer'],
#       dtype='object')

# %%
#q-3 Do any of the columns contain null values? ans:yes.
null_df = df.isnull()
null_df.sum()
# Out:
# id                 0
# name               0
# category           0
# main_category      0
# deadline           0
# goal               0
# launched           0
# state              0
# backers            0
# country            0
# usd_pledged      745
# currency           0
# pledged            0
# dtype: int64

# %%
success_df = (df['state'] == 'successful')
success_df.value_counts()
success1 = df.iloc[success_df.values]
success1
# Out:
#                id                                               name  \
# 1      1100844465                                       daily digest
# 2      1316334968                             Drive A Faster Car 2.0
# 3      1304906577         Accidental to Edinburgh - PHASE 1: AIRFARE
# 4      1099226462          Logical Guess Pictures' 2nd Horror Movie!
# 9      1125367305            Meeting Andrei Tarkovsky - Film Website
# 10     1143904247                            It Might Become a Movie
# 16     1291701547                                    American Summer
# 17     1001181420                                Sleeping in a Truck
# 20     1024509505                      Produce a "Mean" Feature Film
# 22     1036167768                                         Cheap art!
# 24     1216330417  Do It Again: One Man's Quest to Reunite the Kinks
# 25     1358511195               LED Floaties at Hoosac River Lights!
# 29     1021724088                      Help Shwa Make A Record? Yes!
# ...

# %%
##q4 Find all successful documentary projects and sort them by the amount pledged. Print the top 10 highest pledges.
sorted_df = success1.sort_values(by = ['usd_pledged'])
sorted_df.head(10)
# Out:
#                id                                               name  \
# 64410  1130063575  Ginalina: Home Is Family - Share Good Music Wi...
# 60990  1213817873                                WholeSam Food Truck
# 60981  1146476401                                           Sandseer
# 61473  1269555116    'Breaking Breath' - presented by B-Hybrid Dance
# 60956  1165949857  THE ALANA BANANA SHOW APP - a fun & educationa...
# 63931  1133503339        "Don't Be Afraid"-BFA Film by Camille Speer
# 63330  1297980680                    Pirates of Padre Tiempo #1 & #2
# 62509  1089010601                                    The Bike I Like
# 61479  1315988894            Doug McCormick's First-Ever Music Video
# 62263  1225945192                                      Silhouette V2
#
#                category main_category             deadline     goal  \
# 64410              Kids         Music  2016-12-06 08:59:00   3000.0
# 60990       Food Trucks          Food  2016-08-11 17:39:49  10000.0
# ...

# %%
##q-5 The rows with 0 values has resulted in NaN - could be 0 or missing. 
## ans1: We can either use df.fillna('no backers available') or drop them for cleaner data.
df['average_per_backer'] = ((df['usd_pledged']/df['backers']))
df
# Out:
#                id                                               name  \
# 0      1147015301  "All We Had" Gets Into Cannes -- $10 or More G...
# 1      1100844465                                       daily digest
# 2      1316334968                             Drive A Faster Car 2.0
# 3      1304906577         Accidental to Edinburgh - PHASE 1: AIRFARE
# 4      1099226462          Logical Guess Pictures' 2nd Horror Movie!
# 5      1301564845  Anatomy of a Credibility Meltdown — a book abo...
# 6      1081313636  No-bit: An artist book of analog drawings insp...
# 7       112916020          UNINSURED LA™: Support Health Care Reform
# 8      1130941392                             Hand made guitar picks
# 9      1125367305            Meeting Andrei Tarkovsky - Film Website
# 10     1143904247                            It Might Become a Movie
# 11     1163942232             Obscurae: a photo show for Braddock PA
# 12     1167151653                        Smogr Alert Field Recording
# ...

# %%
##q6 Drop all rows with 0 backers then repeat the previous exercise.
df.dropna()
# Out:
#                id                                               name  \
# 0      1147015301  "All We Had" Gets Into Cannes -- $10 or More G...
# 1      1100844465                                       daily digest
# 2      1316334968                             Drive A Faster Car 2.0
# 3      1304906577         Accidental to Edinburgh - PHASE 1: AIRFARE
# 4      1099226462          Logical Guess Pictures' 2nd Horror Movie!
# 5      1301564845  Anatomy of a Credibility Meltdown — a book abo...
# 6      1081313636  No-bit: An artist book of analog drawings insp...
# 7       112916020          UNINSURED LA™: Support Health Care Reform
# 8      1130941392                             Hand made guitar picks
# 9      1125367305            Meeting Andrei Tarkovsky - Film Website
# 10     1143904247                            It Might Become a Movie
# 11     1163942232             Obscurae: a photo show for Braddock PA
# 12     1167151653                        Smogr Alert Field Recording
# ...

# %%
## q-7 Create a crosstab to get a count of records for each combination of state and category.
pd.crosstab(df['state'], df['category'])
# Out:
# category    3D Printing  Academic  Accessories  Action  Animals  Animation  \
# state
# canceled             17        21           48      14        2         41
# failed               59        86          238      79       31        245
# live                  3         3           16       1        0          8
# successful           43        43          121      16       11        134
# suspended             2         4            2       0        1          1
# undefined             1         0            1       0        0          0
#
# category    Anthologies  Apparel  Apps  Architecture  ...  Wearables  Weaving  \
# state                                                 ...
# canceled              4      127   166            10  ...         25        3
# failed               34      684   784            86  ...         71        8
# live                  6       37    28             4  ...          7        0
# ...
