# %%
import pandas as pd
import numpy as np

# %%
flights_df = pd.read_csv('flights.csv')
airlines_df = pd.read_csv('airlines.csv')

# %%
nycflights13_df = pd.merge(flights_df, airlines_df)

# %%
## Q-1 - Merge these two DataFrames into a single DataFrame: nycflights13.

nycflights13_df
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     554.0             558       -4.0     740.0
# 3       2013      1    1     558.0             600       -2.0     924.0
# 4       2013      1    1     558.0             600       -2.0     923.0
# 5       2013      1    1     559.0             600       -1.0     854.0
# 6       2013      1    1     607.0             607        0.0     858.0
# 7       2013      1    1     611.0             600       11.0     945.0
# 8       2013      1    1     623.0             627       -4.0     933.0
# 9       2013      1    1     628.0             630       -2.0    1016.0
# 10      2013      1    1     643.0             646       -3.0     922.0
# 11      2013      1    1     644.0             636        8.0     931.0
# ...

# %%
## q2: Are there any missing values in this DataFrame? If so, drop them.
nycflights13_df.isnull()
# Out:
#          year  month    day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       False  False  False     False           False      False     False
# 1       False  False  False     False           False      False     False
# 2       False  False  False     False           False      False     False
# 3       False  False  False     False           False      False     False
# 4       False  False  False     False           False      False     False
# 5       False  False  False     False           False      False     False
# 6       False  False  False     False           False      False     False
# 7       False  False  False     False           False      False     False
# 8       False  False  False     False           False      False     False
# 9       False  False  False     False           False      False     False
# 10      False  False  False     False           False      False     False
# ...

# %%
## answer
nycflights13_df.dropna()
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     554.0             558       -4.0     740.0
# 3       2013      1    1     558.0             600       -2.0     924.0
# 4       2013      1    1     558.0             600       -2.0     923.0
# 5       2013      1    1     559.0             600       -1.0     854.0
# 6       2013      1    1     607.0             607        0.0     858.0
# 7       2013      1    1     611.0             600       11.0     945.0
# 8       2013      1    1     623.0             627       -4.0     933.0
# 9       2013      1    1     628.0             630       -2.0    1016.0
# 10      2013      1    1     643.0             646       -3.0     922.0
# 11      2013      1    1     644.0             636        8.0     931.0
# ...
